# %%
import scipy.stats as stats
y, x = np.mgrid[-1:1:0.1,-1:1:0.1]
ynorm = stats.norm.pdf(y, loc=0, scale=1)
xnorm = stats.norm.pdf(x, loc=0, scale=1)
gauss = ynorm*xnorm

# %%
imshow(gauss); colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x116c7a200>

# %%
hinton(gauss, gauss, sizes_range=[0.06, 0.15], display_style='circle')

# %%
# Optionally, we might try to make a Hinton map to represent variance
from matplotlib import cm
def hinton(colors, sizes, colors_range=None, sizes_range=None, colormap=cm.jet, bgcolor='w', display_style='square'):
    """
    Draws a Hinton diagram for visualizing a weight matrix.
    """
    assert (display_style == 'square') or (display_style == 'circle'), "display_style can only be declared as 'square' or 'circle'"
    import matplotlib.pyplot as plt
    from matplotlib.patches import Rectangle, Circle
    from matplotlib.ticker import NullLocator

    fig = plt.figure()
    ax = fig.add_subplot(1, 1, 1)

    sizes_range = [sizes.min(), sizes.max()] if sizes_range is None else sizes_range
    sizes = (sizes-sizes_range[0])/(sizes_range[1]-sizes_range[0])
    colors_range = [colors.min(), colors.max()] if colors_range is None else colors_range
    colors = (colors-colors_range[0])/(colors_range[1]-colors_range[0])


    ax.patch.set_facecolor(bgcolor)
    ax.set_aspect('equal', 'box')
    ax.xaxis.set_major_locator(NullLocator())
    ax.yaxis.set_major_locator(NullLocator())

    for (x,y),w in np.ndenumerate(sizes):
        color = colormap(colors[int(x),int(y)])
        size = np.abs(w)
        if display_style == 'square':
           patch = Rectangle([x - size / 2, y - size / 2], size, size, facecolor=color, edgecolor=color)
        elif display_style == 'circle':
            patch = Circle([x - size / 2, y - size / 2], radius=size/2.0, facecolor=color, edgecolor=color)
        ax.add_patch(patch)
    ax.autoscale_view()

    # Reverse the yaxis limits
    ax.set_ylim(*ax.get_ylim()[::-1])
